# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls '/content/drive/MyDrive/DAB103 Final Project'
# Out:
# ls: cannot access '/content/drive/MyDrive/DAB103 Final Project': No such file or directory

# %%
### We will now load the dataset

retail = pd.read_excel('/content/drive/MyDrive/DAB 103 Final Project/Retail_dataset.xlsx', index_col=0)

# %%
retail.index = np.arange(1, len(retail) + 1)
retail
# Out:
#                             customer_id order_status order_purchase_timestamp  \
# 1      7c396fd4830fd04220f754e42b4e5bff    delivered      2017-10-02 10:56:33
# 2      af07308b275d755c9edb36a90c618231    delivered      2018-07-24 20:41:37
# 3      3a653a41f6f9fc3d2a113cf8398680e8    delivered      2018-08-08 08:38:49
# 4      7c142cf63193a1473d2e66489a9ae977    delivered      2017-11-18 19:28:06
# 5      72632f0f9dd73dfee390c9b22eb56dd6    delivered      2018-02-13 21:18:39
# ...                                 ...          ...                      ...
# 99437  6359f309b166b0196dbf7ad2ac62bb5a    delivered      2017-03-09 09:54:05
# 99438  da62f9e57a76d978d02ab5362c509660    delivered      2018-02-06 12:58:58
# 99439  737520a9aad80b3fbbdad19b66b37b30    delivered      2017-08-27 14:46:43
# 99440  5097a5312c8b157bb7be58ae360ef43c    delivered      2018-01-08 21:28:27
# 99441  60350aa974b26ff12caad89e55993bd6    delivered      2018-03-08 20:57:30
#
# ...

# %%
## We will now find the type of the dataset

type(retail)
# Out:
# pandas.core.frame.DataFrame

# %%
## Displaying first 15 rows of the dataset for an overview of data

retail.head(15)
# Out:
#                          customer_id order_status order_purchase_timestamp  \
# 1   7c396fd4830fd04220f754e42b4e5bff    delivered      2017-10-02 10:56:33
# 2   af07308b275d755c9edb36a90c618231    delivered      2018-07-24 20:41:37
# 3   3a653a41f6f9fc3d2a113cf8398680e8    delivered      2018-08-08 08:38:49
# 4   7c142cf63193a1473d2e66489a9ae977    delivered      2017-11-18 19:28:06
# 5   72632f0f9dd73dfee390c9b22eb56dd6    delivered      2018-02-13 21:18:39
# 6   80bb27c7c16e8f973207a5086ab329e2    delivered      2017-07-09 21:57:05
# 7   36edbb3fb164b1f16485364b6fb04c73     invoiced      2017-04-11 12:22:08
# 8   932afa1e708222e5821dac9cd5db4cae    delivered      2017-05-16 13:10:30
# 9   39382392765b6dc74812866ee5ee92a7    delivered      2017-01-23 18:29:09
# 10  299905e3934e9e181bfb2e164dd4b4f8    delivered      2017-07-29 11:55:02
# 11  f2a85dec752b8517b5e58a06ff3cd937    delivered      2017-05-16 19:41:10
# ...

# %%
## Displaying the last 15 rows of the dataset for an overview of data

retail.tail(15)
# Out:
#                             customer_id order_status order_purchase_timestamp  \
# 99427  7bb6ca43f478742340256d516d9d86e3    delivered      2017-05-15 09:46:26
# 99428  9e4accf95024aa6565ca1efcadb96752    delivered      2018-05-12 13:42:24
# 99429  e930b415f39ab827ea66de80a9d36a22    delivered      2018-06-22 20:53:29
# 99430  22757c044f096bef19c36c5d6ffc51d5    delivered      2017-11-05 16:17:53
# 99431  324a22205906aa2612a33e63c00ca8bb    delivered      2018-03-04 22:48:38
# 99432  1a3b8f1d0782ebedbcf220a96cbc1655    delivered      2017-10-27 15:21:00
# 99433  a49e8e11e850592fe685ae3c64b40eca    delivered      2017-12-20 09:52:41
# 99434  c716cf2b5b86fb24257cffe9e7969df8    delivered      2017-10-04 19:57:37
# 99435  e03dbdf5e56c96b106d8115ac336f47f    delivered      2017-01-27 00:30:03
# 99436  831ce3f1bacbd424fc4e38fbd4d66d29    delivered      2017-02-23 09:05:12
# 99437  6359f309b166b0196dbf7ad2ac62bb5a    delivered      2017-03-09 09:54:05
# ...

# %%
## Finding the shape of the dataset for displaying the number of rows and columns

retail.shape
# Out:
# (99441, 23)

# %%
## Dispaying the total number of rows for better understanding

retail.shape[0]
# Out:
# 99441

# %%
## Dispaying the total number of columns for better understanding

retail.shape[1]
# Out:
# 23

# %%
## We are now going to find the information about the dataset 

retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99441 entries, 1 to 99441
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_id                    99441 non-null  object
#  1   order_status                   99441 non-null  object
#  2   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  3   order_approved_at              99281 non-null  datetime64[ns]
#  4   order_delivered_timestamp      96476 non-null  datetime64[ns]
#  5   order_estimated_delivery_date  99441 non-null  datetime64[ns]
#  6   order_item_id                  55282 non-null  float64
#  7   product_id                     55282 non-null  object
#  8   seller_id                      55282 non-null  object
#  9   price                          55282 non-null  float64
#  10  shipping_charges               55282 non-null  float64
# ...

# %%
## from the above data we see that there are many null values in the dataset, hence we are going to find the null values column wise

retail.isna().sum().sum()
# Out:
# 980663

# %%
## Now we are going to describe the dataset, Describe specifies the details of every column in terms of count,mean, standard deviation, minimum and maximum values and the different percetiles

retail.describe()
# Out:
#        order_item_id         price  shipping_charges  \
# count        55282.0  55282.000000      55282.000000
# mean             1.0    126.013761         20.142267
# std              0.0    193.635747         15.810831
# min              1.0      2.200000          0.000000
# 25%              1.0     41.800000         13.280000
# 50%              1.0     79.000000         16.350000
# 75%              1.0    139.900000         21.150000
# max              1.0   6729.000000        409.680000
#
#        customer_zip_code_prefix  payment_sequential  payment_installments  \
# count              50865.000000        52542.000000          52542.000000
# mean               35122.551145            1.031327              2.888699
# std                29779.563599            0.270077              2.702280
# min                 1003.000000            1.000000              0.000000
# 25%                11431.000000            1.000000              1.000000
# ...

# %%
## Now we check the overall correlations 

retail.corr()
corr = retail.corr()
corr
# Out:
#                           order_item_id     price  shipping_charges  \
# order_item_id                       NaN       NaN               NaN
# price                               NaN  1.000000          0.424773
# shipping_charges                    NaN  0.424773          1.000000
# customer_zip_code_prefix            NaN  0.042416          0.229863
# payment_sequential                  NaN  0.003495          0.004145
# payment_installments                NaN  0.309744          0.204753
# payment_value                       NaN  0.928333          0.474498
# product_weight_g                    NaN  0.314105          0.592466
# product_length_cm                   NaN  0.124262          0.286053
# product_height_cm                   NaN  0.212686          0.389101
# product_width_cm                    NaN  0.154830          0.303231
#
#                           customer_zip_code_prefix  payment_sequential  \
# order_item_id                                  NaN                 NaN
# ...

# %%
corr.style.background_gradient(cmap ='coolwarm')
# Out:
# <style type="text/css">
# #T_573a7_row0_col0, #T_573a7_row0_col1, #T_573a7_row0_col2, #T_573a7_row0_col3, #T_573a7_row0_col4, #T_573a7_row0_col5, #T_573a7_row0_col6, #T_573a7_row0_col7, #T_573a7_row0_col8, #T_573a7_row0_col9, #T_573a7_row0_col10, #T_573a7_row1_col0, #T_573a7_row2_col0, #T_573a7_row3_col0, #T_573a7_row4_col0, #T_573a7_row5_col0, #T_573a7_row6_col0, #T_573a7_row7_col0, #T_573a7_row8_col0, #T_573a7_row9_col0, #T_573a7_row10_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_573a7_row1_col1, #T_573a7_row2_col2, #T_573a7_row3_col3, #T_573a7_row4_col4, #T_573a7_row5_col5, #T_573a7_row6_col6, #T_573a7_row7_col7, #T_573a7_row8_col8, #T_573a7_row9_col9, #T_573a7_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_573a7_row1_col2, #T_573a7_row2_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_573a7_row1_col3, #T_573a7_row3_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# ...

# %%
rtl = pd.DataFrame(retail)

print(rtl.dtypes)
# Out:
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_timestamp        datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# order_item_id                           float64
# product_id                               object
# seller_id                                object
# price                                   float64
# shipping_charges                        float64
# customer_zip_code_prefix                float64
# customer_city                            object
# customer_state                           object
# payment_sequential                      float64
# payment_type                             object
# payment_installments                    float64
# payment_value                           float64
# product_category_name                    object
# product_weight_g                        float64
# ...

# %%
##We will now make a histogram for price column

PLOT = plt.hist(retail.price, bins=10)
plt.show()

# %%
## Since, we can clearly see in the info output that we have got null values in order_approved_at and order_delivered_timestamp,
## we will now treat them by replacing the values using the values from other columns 
## order_purchase_timestamp and order_estimated_delivery_date respectively

retail.order_approved_at.fillna(retail.order_purchase_timestamp, inplace=True)
retail.order_delivered_timestamp.fillna(retail.order_estimated_delivery_date, inplace=True)

retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99441 entries, 1 to 99441
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_id                    99441 non-null  object
#  1   order_status                   99441 non-null  object
#  2   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  3   order_approved_at              99441 non-null  datetime64[ns]
#  4   order_delivered_timestamp      99441 non-null  datetime64[ns]
#  5   order_estimated_delivery_date  99441 non-null  datetime64[ns]
#  6   order_item_id                  55282 non-null  float64
#  7   product_id                     55282 non-null  object
#  8   seller_id                      55282 non-null  object
#  9   price                          55282 non-null  float64
#  10  shipping_charges               55282 non-null  float64
# ...

# %%
## Now we will check if there are any duplicate values in the customer_id column

retail.customer_id.duplicated().sum()
# Out:
# 3345

# %%
## Now we will check if there are any duplicate values in the order_purchase_timestamp column

retail.order_purchase_timestamp.duplicated().sum()
# Out:
# 566

# %%
## We will find the max price of the product being sold

retail['MAX range'] = retail['price'].max()
retail["price"].max()
# Out:
# 6729.0

# %%
## We will find the least priced porduct being sold
retail['min range'] = retail['price'].min()
retail["price"].min()
# Out:
# 2.2

# %%
## We will find the average pricing of all the products being sold

retail['mean'] = retail['price'].mean()
retail["price"].mean()
# Out:
# 126.01376089866505

# %%
## We will now make a box plot to understand the outliers

retail['price'].plot(kind='box', title='Price density', color='green')

# %%
## We will find the maximum shipping_charges incurred on porducts being sold

retail['MAX range'] = retail['shipping_charges'].max()
retail["shipping_charges"].max()
# Out:
# 409.68

# %%
## We will find the minimum shipping_charges incurred on products being sold

retail['MIN range'] = retail['shipping_charges'].min()
retail["shipping_charges"].min()
# Out:
# 0.0

# %%
## We will find the average shipping_charges incurred on all the products being sold

retail['mean range'] = retail['shipping_charges'].mean()
retail["shipping_charges"].mean()
# Out:
# 20.14226692232553

# %%
## We will now make a box plot to understand the outliers

retail['shipping_charges'].plot(kind='box', title='Shipping_charges Desnity', color='red')

# %%
retail.plot(x = 'customer_zip_code_prefix', y = 'price')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
## We would now make a histogram to understand the distribution of customer base

PLOT = plt.hist(retail.customer_zip_code_prefix, bins=10, color = 'purple')
plt.show()

# %%
## We will now try to find the null values in payments table

retail.order_item_id.isna().sum()
# Out:
# 44159

# %%
retail.payment_sequential.isna().sum()
# Out:
# 46899

# %%
retail.payment_type.isna().sum()
# Out:
# 46899

# %%
retail.payment_installments.isna().sum()
# Out:
# 46899

# %%
retail.payment_value.isna().sum()
# Out:
# 46899

# %%
## Now we will replace the null vlaues in the payment_type with not_defined

retail.order_item_id.fillna(retail.customer_id, inplace=True)
retail.product_id.fillna("not_captured")
retail.seller_id.fillna("not_captured", inplace=True)
retail.payment_type.fillna("not_defined", inplace=True)
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99441 entries, 1 to 99441
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_id                    99441 non-null  object
#  1   order_status                   99441 non-null  object
#  2   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  3   order_approved_at              99441 non-null  datetime64[ns]
#  4   order_delivered_timestamp      99441 non-null  datetime64[ns]
#  5   order_estimated_delivery_date  99441 non-null  datetime64[ns]
#  6   order_item_id                  99441 non-null  object
#  7   product_id                     55282 non-null  object
#  8   seller_id                      99441 non-null  object
#  9   price                          55282 non-null  float64
#  10  shipping_charges               55282 non-null  float64
# ...

# %% [markdown]
# # **After exploring the dataset and treating the null values now we can see that there are no duplicate values remaining in the retail dataset.**

# %%
retail.duplicated( keep='first').sum()
# Out:
# 0

# %% [markdown]
# Pie Chart to understand the amount of people using the different modes of payment

# %%
import matplotlib.pyplot as plt

ptype = ['CREDIT', 'DEBIT', 'VOUCHER', 'WALLET']
pvalue = [12542084.19, 217989.79, 379436.87, 2869361.27]
myexplode = [0.2, 0.2, 0.1, 0]
fig = plt.figure(figsize =(10, 7))
plt.pie(pvalue, labels = ptype, colors=['#FF5733','#00F613','#F600DC','#3333FF'], explode = myexplode, shadow = True)
plt.legend()
plt.show()
